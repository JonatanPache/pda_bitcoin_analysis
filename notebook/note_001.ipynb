# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r'/home/yeat/Documents/cursos/Udemy - Data Analysis Real world use-cases- Hands on Python 2024-1/4 - Project 2 Bitcoin Data Analysis/19 - Bitcoin/bitcoin_price_Training - Training.csv')
df.head(3)
# Out:
#            Date     Open     High      Low    Close       Volume  \
# 0  Jul 31, 2017  2763.24  2889.62  2720.61  2875.34  860,575,000
# 1  Jul 30, 2017  2724.39  2758.53  2644.85  2757.18  705,943,000
# 2  Jul 29, 2017  2807.02  2808.76  2692.80  2726.45  803,746,000
#
#        Market Cap
# 0  45,535,800,000
# 1  44,890,700,000
# 2  46,246,700,000

# %%
df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Market Cap'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1556 entries, 0 to 1555
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        1556 non-null   object
#  1   Open        1556 non-null   float64
#  2   High        1556 non-null   float64
#  3   Low         1556 non-null   float64
#  4   Close       1556 non-null   float64
#  5   Volume      1556 non-null   object
#  6   Market Cap  1556 non-null   object
# dtypes: float64(4), object(3)
# memory usage: 85.2+ KB

# %%
df.describe()
# Out:
#               Open         High          Low        Close
# count  1556.000000  1556.000000  1556.000000  1556.000000
# mean    582.625328   597.992847   567.851446   584.239396
# std     523.137312   542.992855   505.877401   525.904442
# min      68.500000    74.560000    65.530000    68.430000
# 25%     254.287500   260.327500   248.835000   254.320000
# 50%     438.600000   447.560000   430.570000   438.855000
# 75%     662.437500   674.525000   646.735000   663.402500
# max    2953.220000  2999.910000  2840.530000  2958.110000

# %%
df.describe().T
# Out:
#         count        mean         std    min       25%      50%       75%  \
# Open   1556.0  582.625328  523.137312  68.50  254.2875  438.600  662.4375
# High   1556.0  597.992847  542.992855  74.56  260.3275  447.560  674.5250
# Low    1556.0  567.851446  505.877401  65.53  248.8350  430.570  646.7350
# Close  1556.0  584.239396  525.904442  68.43  254.3200  438.855  663.4025
#
#            max
# Open   2953.22
# High   2999.91
# Low    2840.53
# Close  2958.11

# %% [markdown]
# # data processing

# %%
df.dtypes
# Out:
# Date           object
# Open          float64
# High          float64
# Low           float64
# Close         float64
# Volume         object
# Market Cap     object
# dtype: object

# %%
df['Date'] = df['Date'].astype('datetime64[ns]')

# %%
df['Date'].min()
# Out:
# Timestamp('2013-04-28 00:00:00')

# %%
df.isnull().sum()
# Out:
# Date          0
# Open          0
# High          0
# Low           0
# Close         0
# Volume        0
# Market Cap    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.sort_index(ascending=False).reset_index()
# Out:
#       index       Date     Open     High      Low    Close         Volume  \
# 0      1555 2013-04-28   135.30   135.98   132.10   134.21              -
# 1      1554 2013-04-29   134.44   147.49   134.00   144.54              -
# 2      1553 2013-04-30   144.00   146.93   134.05   139.00              -
# 3      1552 2013-05-01   139.00   139.89   107.72   116.99              -
# 4      1551 2013-05-02   116.38   125.60    92.28   105.21              -
# ...     ...        ...      ...      ...      ...      ...            ...
# 1551      4 2017-07-27  2538.71  2693.32  2529.34  2671.78    789,104,000
# 1552      3 2017-07-28  2679.73  2897.45  2679.73  2809.01  1,380,100,000
# 1553      2 2017-07-29  2807.02  2808.76  2692.80  2726.45    803,746,000
# 1554      1 2017-07-30  2724.39  2758.53  2644.85  2757.18    705,943,000
# 1555      0 2017-07-31  2763.24  2889.62  2720.61  2875.34    860,575,000
#
#           Market Cap
# 0      1,500,520,000
# 1      1,491,160,000
# ...

# %% [markdown]
# # Change prive overtime

# %%
# drop index column
df.drop('index', axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 2
#       1 # drop index column
# ----> 2 df.drop('index', axis=1, inplace=True)
#
# File ~/.local/share/virtualenvs/pda_btc_analysis-QvI4XNL5/lib64/python3.13/site-packages/pandas/core/frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
# ...

# %%
plt.figure(figsize=(20,12))
for index, col in enumerate(['Open','High','Low','Close'], 1):
    plt.subplot(2,2,index)
    plt.plot(df['Date'], df[col])
    plt.title(col)
